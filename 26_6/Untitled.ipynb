# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("./titanic.csv")

# %%
data[55:96]
# Out:
#     PassengerId  Survived  Pclass  \
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
# 60           61         0       3
# 61           62         1       1
# 62           63         0       1
# 63           64         0       3
# 64           65         0       1
# 65           66         1       3
# 66           67         1       2
# 67           68         0       3
# 68           69         1       3
# 69           70         0       3
# 70           71         0       2
# 71           72         0       3
# 72           73         0       2
# 73           74         0       3
# 74           75         1       3
# 75           76         0       3
# 76           77         0       3
# 77           78         0       3
# 78           79         1       2
# 79           80         1       3
# 80           81         0       3
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
not_useful=['PassengerId','Name','Ticket','Cabin','Embarked']

# %%
data_clean=data.drop(columns=not_useful)

# %%
data_clean.shape
# Out:
# (891, 7)

# %%
data_clean.head(50)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch      Fare
# 0          0       3    male  22.0      1      0    7.2500
# 1          1       1  female  38.0      1      0   71.2833
# 2          1       3  female  26.0      0      0    7.9250
# 3          1       1  female  35.0      1      0   53.1000
# 4          0       3    male  35.0      0      0    8.0500
# 5          0       3    male   NaN      0      0    8.4583
# 6          0       1    male  54.0      0      0   51.8625
# 7          0       3    male   2.0      3      1   21.0750
# 8          1       3  female  27.0      0      2   11.1333
# 9          1       2  female  14.0      1      0   30.0708
# 10         1       3  female   4.0      1      1   16.7000
# 11         1       1  female  58.0      0      0   26.5500
# 12         0       3    male  20.0      0      0    8.0500
# 13         0       3    male  39.0      1      5   31.2750
# 14         0       3  female  14.0      0      0    7.8542
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
le?

# %%
temp=["A","B","C","A"]
le.fit_transform(temp)
# Out:
# array([0, 1, 2, 0], dtype=int64)

# %%
temp2=["A","C","B"]

# %%
le.transform(temp2)
# Out:
# array([0, 2, 1], dtype=int64)

# %%
data_clean['Sex']=le.fit_transform(data_clean['Sex'])

# %%
data_clean.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    1  22.0      1      0   7.2500
# 1         1       1    0  38.0      1      0  71.2833
# 2         1       3    0  26.0      0      0   7.9250
# 3         1       1    0  35.0      1      0  53.1000
# 4         0       3    1  35.0      0      0   8.0500

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int32
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# dtypes: float64(2), int32(1), int64(4)
# memory usage: 45.3 KB

# %%
data_clean.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
data_clean['Age'].mean()
# Out:
# 29.69911764705882

# %%
data_clean=data_clean.fillna(data_clean['Age'].mean())

# %%
data_clean.fillna?

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null int32
# Age         891 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# dtypes: float64(2), int32(1), int64(4)
# memory usage: 45.3 KB

# %%
def entropy(col):
    counts=np.unique(col,return_counts=True)
    ent=0.0
    N=float(col.shape[0])
    #print(counts)
    for ix in counts[1]:
        p=ix/N
        ent+=-(p*np.log2(p))
    return ent

# %%
entropy(data_clean['Sex'])
# Out:
# 0.9362046432498521

# %%
def split_data(X_data,fkey,fval):
    #Binary Split
    X_Right=pd.DataFrame([],columns=X_data.columns)
    X_Left= pd.DataFrame([],columns=X_data.columns)
    for ix in range(X_data.shape[0]):
        val=X_data[fkey].loc[ix]
        
        if val>fval:
            X_Right=X_Right.append(X_data.loc[ix])
        else:
            X_Left=X_Left.append(X_data.loc[ix])
    return X_Right,X_Left

# %%
R,L=split_data(data_clean,'Sex',0.5)

# %%
R.head(4)
# Out:
#    Survived  Pclass  Sex        Age  SibSp  Parch     Fare
# 0       0.0     3.0  1.0  22.000000    1.0    0.0   7.2500
# 4       0.0     3.0  1.0  35.000000    0.0    0.0   8.0500
# 5       0.0     3.0  1.0  29.699118    0.0    0.0   8.4583
# 6       0.0     1.0  1.0  54.000000    0.0    0.0  51.8625

# %%
L.head(3)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 1       1.0     1.0  0.0  38.0    1.0    0.0  71.2833
# 2       1.0     3.0  0.0  26.0    0.0    0.0   7.9250
# 3       1.0     1.0  0.0  35.0    1.0    0.0  53.1000

# %%
def info_gain(X_data,fkey,fval):
    right,left=split_data(X_data,fkey,fval)
    #Weight
    l=float(left.shape[0]/X_data.shape[0])
    r=float(left.shape[0]/X_data.shape[0])
    
    
    if left.shape[0]==0 or right.shape[0]==0:
        return -10000
    
    i_gain=entropy(X_data.Survived)-l*entropy(left.Survived)-r*entropy(right.Survived)
    return i_gain

# %%
info_gain(data_clean,'Sex',0.5)
# Out:
# 0.4240403654022318

# %%
data_clean.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
 max=0
for i in data_clean.columns:
    ml=""
    m=info_gain(data_clean,i,data_clean[i].mean())
    if m>max and i!='Survived':
        max=m
        ml=i
       
print(i,max,"j")
# Out:
# Fare 0.4240403654022318 j

# %%
for i in data_clean.columns:
    print(i)
# Out:
# Survived
# Pclass
# Sex
# Age
# SibSp
# Parch
# Fare

# %%
class DecisionTree:
    def __init__(self,depth=0,max_depth=5):
        self.right=None
        self.left=None
        self.fkey=None
        self.max_depth=max_depth
        self.depth=depth
        self.target=None
        
    def train(self,X_train):
        features=['Pclass',"Sex","Age","SibSp","Parch","Fare"]
        
        info_gain_list=[]
        
        for ix in features:
            i_gain=info_gain(X_train,ix,X_train[ix].mean())
            info_gain_list.append(i_gain)
            
           
        selected=features[np.argmax(info_gain)] 
        self.fkey=selected
        self.fval=X_train[selected].mean()
            
        data_left,data_right=split_data(X_train,self.fkey,self.fval)
        data_right=data_left.reset_index(drop=True)
        data_left=data_right.reset_index(drop=True)
        # Base Case Leaf node
        if(data_left.shape[0]==0 or dataright.shape[0]==0):
            if(X_train.Survived.mean()>0.5):
                self.target="Survived"
            else:
                self.target="Dead"
        
            return
        # Base max depth
        if(self.depth>=self.max_depth):
        
            return self.target
        #Recursive Case
        #Create left node
        
        self.left=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
       #Recursively BUild the left subtree
        self.left.train(data_left)
        
        self.right=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.right.train(data_right)
       
        if(X_train.Survived.mean()>0.5):
            self.target="Survived"
        else:
            self.target="Dead"
            return
        def predict(self,test):
            if test[self.fkey]>self.fval:
                if self.right.predict(test) is None:
                    return self.target
                return self.right.predict(test)
            else:
                if self.left is None:
                    return self.target
                return self.left.predict

# %%
split=int(0.7*(data_clean.shape[0]))

# %%
train_data=data_clean[:split]
test_data=data_clean[split:]

# %%
test_data.head(4)
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 623         0       3    1  21.0      0      0   7.8542
# 624         0       3    1  21.0      0      0  16.1000
# 625         0       1    1  61.0      0      0  32.3208
# 626         0       2    1  57.0      0      0  12.3500

# %%
test_data=test_data.reset_index()

# %%
test_data
# Out:
#      index  Survived  Pclass  Sex        Age  SibSp  Parch     Fare
# 0      623         0       3    1  21.000000      0      0   7.8542
# 1      624         0       3    1  21.000000      0      0  16.1000
# 2      625         0       1    1  61.000000      0      0  32.3208
# 3      626         0       2    1  57.000000      0      0  12.3500
# 4      627         1       1    0  21.000000      0      0  77.9583
# 5      628         0       3    1  26.000000      0      0   7.8958
# 6      629         0       3    1  29.699118      0      0   7.7333
# 7      630         1       1    1  80.000000      0      0  30.0000
# 8      631         0       3    1  51.000000      0      0   7.0542
# 9      632         1       1    1  32.000000      0      0  30.5000
# 10     633         0       1    1  29.699118      0      0   0.0000
# 11     634         0       3    0   9.000000      3      2  27.9000
# 12     635         1       2    0  28.000000      0      0  13.0000
# ...

# %%
train_data.shape
# Out:
# (623, 7)

# %%
test_data.shape
# Out:
# (268, 8)

# %%
dt=DecisionTree()

# %%
dt.train(train_data)

# %%
y_pred=[]

for ix in range(test_data.shape[0]):
    pred=dt.predict(test_data,)
